# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import mahotas as mh
import numpy as np
import os
import json
import multiprocessing
from math import floor
from time import time
from skimage import io, color, img_as_ubyte, img_as_float
from skimage.transform import rescale
from skimage.morphology import label
from skimage.util import pad
from sklearn.decomposition import PCA, RandomizedPCA
from sklearn.cluster import DBSCAN
from scipy.cluster.vq import kmeans2
from IPython.parallel import Client

from helpers import display, features, morphology

BASE_PATH = os.getcwd()
print("Current base path: {0}".format(BASE_PATH))
DATA_PATH = BASE_PATH + '/Daten/2D/Talus_dorsal_cut_2/'
TO_PATH = BASE_PATH + '/Daten/2D/Talus_dorsal_outlined/'
TEST_FILES = json.loads(open(BASE_PATH + '/Daten/2D/testfiles.json').read())

WINDOW_HEIGHT = 0
WINDOW_WIDTH = 25

def extract_semi_localities_for_each_pixel_x(image):
    image_with_padded_borders = np.pad(image, ((WINDOW_HEIGHT, WINDOW_HEIGHT), (WINDOW_WIDTH, WINDOW_WIDTH), (0, 0)), mode='symmetric')
    neighborhoods = np.zeros((image.shape[0] * image.shape[1], 2, WINDOW_WIDTH, 3), dtype=np.uint8)
    
    for y in range(image.shape[0]):
        for x in range(image.shape[1]):
            neighborhoods[y*image.shape[1] + x, 0, :, :] = image_with_padded_borders[y:y+2*WINDOW_HEIGHT+1, x:x+WINDOW_WIDTH, :]
            neighborhoods[y*image.shape[1] + x, 1, :, :] = image_with_padded_borders[y:y+2*WINDOW_HEIGHT+1, x+WINDOW_WIDTH:x+2*WINDOW_WIDTH, :]
            
    return neighborhoods

def extract_semi_localities_for_each_pixel_y(image):
    image_with_padded_borders = np.pad(image, ((WINDOW_WIDTH, WINDOW_WIDTH), (WINDOW_HEIGHT, WINDOW_HEIGHT), (0, 0)), mode='symmetric')
    neighborhoods = np.zeros((image.shape[0] * image.shape[1], 2, WINDOW_WIDTH, 3), dtype=np.uint8)
    
    for y in range(image.shape[0]):
        for x in range(image.shape[1]):
            neighborhoods[y*image.shape[1] + x, 0, :, :] = image_with_padded_borders[y:y+WINDOW_WIDTH, x:x+2*WINDOW_HEIGHT+1, :].transpose((1, 0 ,2))
            neighborhoods[y*image.shape[1] + x, 1, :, :] = image_with_padded_borders[y+WINDOW_WIDTH:y+2*WINDOW_WIDTH, x:x+2*WINDOW_HEIGHT+1, :].transpose((1, 0 ,2))
            
    return neighborhoods

def extract_semi_localities_for_each_pixel(image):
    return np.concatenate((extract_semi_localities_for_each_pixel_x(image), extract_semi_localities_for_each_pixel_y(image)), axis=1)

def map_feature_for_pixel(neighborhood):
    import numpy as np
    import mahotas as mh
       
    neighborhood_left = neighborhood[0]
    neighborhood_right = neighborhood[1]
    neighborhood_top = neighborhood[2].transpose()
    neighborhood_bottom = neighborhood[3].transpose()
    har_left = mh.features.haralick(neighborhood_left)
    har_right = mh.features.haralick(neighborhood_right)
    har_top = mh.features.haralick(neighborhood_top)
    har_bottom = mh.features.haralick(neighborhood_bottom)
    
    dist_x = np.linalg.norm(har_left - har_right)
    dist_y = np.linalg.norm(har_top - har_bottom)
    
    return dist_x + dist_y

def process_features_for_single_image(image):
    neighborhoods = extract_semi_localities_for_each_pixel(image)
    
    features = np.array(list(map(map_feature_for_pixel, neighborhoods)))
    
    #features = features.normalize_each(features)
    features = features.normalize(features)
    
    return features

def reduce_feature_complexity(features):
    pca = PCA(n_components=6)
    #pca = RandomizedPCA(n_components=6)
    reduced = pca.fit_transform(features)
    return reduced
        
def do_clustering(features):
    centroids, labels = kmeans2(features, 2)
    return labels
# Out:
# Current base path: C:\Users\Stefan\Dropbox\Masterarbeit

# %%
file = TEST_FILES[3]
rgb_image = io.imread(DATA_PATH + file['filename'])
rgb_image = img_as_ubyte(rescale(rgb_image, .1))
hsv_image = img_as_ubyte(color.rgb2hsv(rgb_image))

start_time = time()
features = process_features_for_single_image(rgb_image)
print('apply_filter: {0}s'.format(time() - start_time))

# %%
display.features(features)
# Out:
# [ 0.02005019  0.0101653   0.01002092 ...,  0.02025623  0.01482857
#   0.01434752]
# [[[ 68  88 144]
#   [ 43  67 154]
#   [ 54  83 162]
#   ...,
#   [ 31  45 108]
#   [ 11  22  67]
#   [ 25  36  94]]
#
#  [[ 44  75 147]
#   [ 54  80 160]
#   [ 62  92 165]
#   ...,
#   [ 33  57 130]
#   [ 12  22  66]
#   [ 12  21  65]]
#
#  [[ 24  46 133]
#   [ 47  76 156]
#   [ 47  76 154]
#   ...,
#   [ 23  42 110]
#   [ 15  27  77]
#   [ 23  35  84]]
#
#  ...,
#  [[ 26  49 128]
#   [ 41  72 161]
#   [ 73 106 177]
#   ...,
#   [ 41  64 134]
#   [ 36  64 138]
#   [ 38  64 141]]
#
#  [[ 47  78 158]
#   [ 36  62 149]
#   [ 51  83 166]
#   ...,
#   [ 44  71 141]
#   [ 42  69 139]
#   [ 40  63 139]]
#
#  [[ 42  73 153]
#   [ 61  89 162]
#   [130 142 183]
#   ...,
#   [ 32  48 107]
#   [ 17  33  92]
#   [ 33  52 110]]]
# <img src="data:image/png;base64,...">

# %%
reduced = reduce_feature_complexity(features)

# %%
display.features(reduced)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
labels = do_clustering(reduced)
labels = labels.reshape((rgb_image.shape[0], rgb_image.shape[1]))

# %%
display.clusters(rgb_image, labels)
