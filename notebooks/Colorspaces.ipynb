# %% [markdown]
# # Colorspaces Evaluation

# %%
# %pylab nbagg

import os
import json
import numpy as np
from skimage import io, color

BASE_PATH = os.getcwd()
print("Current base path: {0}".format(BASE_PATH))
DATA_PATH = BASE_PATH + '/Daten/2D/Talus_dorsal_cut_2/'
TEST_FILES = json.loads(open(BASE_PATH + '/Daten/2D/testfiles.json').read())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Current base path: /home/stefan/Dropbox/Masterarbeit

# %% [markdown]
# ## RGB

# %%
filename = TEST_FILES[5]['filename']

talus = io.imread(DATA_PATH + filename)
talus_hed = talus

foreground_indices_rows = np.array(TEST_FILES[2]['foreground'])[:,0]
foreground_indices_columns = np.array(TEST_FILES[2]['foreground'])[:,1]
talus[foreground_indices_rows, foreground_indices_columns, 1] = 255

background_indices_rows = np.array(TEST_FILES[2]['background'])[:,0]
background_indices_columns = np.array(TEST_FILES[2]['background'])[:,1]
talus[background_indices_rows, background_indices_columns, 0] = 255
print(talus[background_indices_rows, background_indices_columns].shape)

fig, ax = plt.subplots(2, 2)
ax[0][0].imshow(talus)
ax[0][0].set_title("RGB")
ax[0][1].imshow(color.gray2rgb(talus_hed[:,:,0]))
ax[0][1].set_title("RGB 1")
ax[1][0].imshow(color.gray2rgb(talus_hed[:,:,1]))
ax[1][0].set_title("RGB 2")
ax[1][1].imshow(color.gray2rgb(talus_hed[:,:,2]))
ax[1][1].set_title("RGB 3")
# Out:
# (26, 3)
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## HED

# %%
filename = 'MiZ08-465R_9.JPG'

talus = io.imread(DATA_PATH + filename)
talus_hed = color.rgb2hed(talus)

fig, ax = plt.subplots(2, 2)
ax[0][0].imshow(talus)
ax[0][0].set_title("RGB")
ax[0][1].imshow(color.gray2rgb(talus_hed[:,:,0]))
ax[0][1].set_title("HED 1")
ax[1][0].imshow(color.gray2rgb(talus_hed[:,:,1]))
ax[1][0].set_title("HED 2")
ax[1][1].imshow(color.gray2rgb(talus_hed[:,:,2]))
ax[1][1].set_title("HED 3")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## HSV

# %%
filename = TEST_FILES[2]['filename']

talus = io.imread(DATA_PATH + filename)
talus_hed = color.rgb2hsv(talus)

io.imsave('/home/stefan/tmp/talus.jpg', talus_hed[:,:,0])

fig, ax = plt.subplots(2, 2)
ax[0][0].imshow(talus)
ax[0][0].set_title("RGB")
ax[0][1].imshow(color.gray2rgb(talus_hed[:,:,0]))
ax[0][1].set_title("HSV 1")
ax[1][0].imshow(color.gray2rgb(talus_hed[:,:,1]))
ax[1][0].set_title("HSV 2")
ax[1][1].imshow(color.gray2rgb(talus_hed[:,:,2]))
ax[1][1].set_title("HSV 3")

# %% [markdown]
# ## LAB

# %%
filename = 'GÜ2011_GÜ17_R.JPG'

talus = io.imread(DATA_PATH + filename)
talus_hed = color.rgb2lab(talus)

talus_hed[:,:,0] = np.divide(talus_hed[:,:,0], talus_hed[:,:,0].max())
talus_hed[:,:,1] = np.divide(talus_hed[:,:,1], talus_hed[:,:,1].max())
talus_hed[:,:,2] = np.divide(talus_hed[:,:,2], talus_hed[:,:,2].max())

fig, ax = plt.subplots(2, 2)
ax[0][0].imshow(talus)
ax[0][0].set_title("RGB")
ax[0][1].imshow(color.gray2rgb(talus_hed[:,:,0]))
ax[0][1].set_title("LAB 1")
ax[1][0].imshow(color.gray2rgb(talus_hed[:,:,1]))
ax[1][0].set_title("LAB 2")
ax[1][1].imshow(color.gray2rgb(talus_hed[:,:,2]))
ax[1][1].set_title("LAB 3")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## LUV

# %%
filename = 'MiZ08-465R_9.JPG'
talus = io.imread(DATA_PATH + filename)

talus_hed = color.rgb2luv(talus)
talus_hed[:,:,0] = np.divide(talus_hed[:,:,0], talus_hed[:,:,0].max())
talus_hed[:,:,1] = np.divide(talus_hed[:,:,1], talus_hed[:,:,1].max())
talus_hed[:,:,2] = np.divide(talus_hed[:,:,2], talus_hed[:,:,2].max())

fig, ax = plt.subplots(2, 2)
ax[0][0].imshow(talus)
ax[0][0].set_title("RGB")
ax[0][1].imshow(color.gray2rgb(talus_hed[:,:,0]))
ax[0][1].set_title("LUV 1")
ax[1][0].imshow(color.gray2rgb(talus_hed[:,:,1]))
ax[1][0].set_title("LUV 2")
ax[1][1].imshow(color.gray2rgb(talus_hed[:,:,2]))
ax[1][1].set_title("LUV 3")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## XYZ

# %%
filename = 'MiZ08-465R_9.JPG'
talus = io.imread(DATA_PATH + filename)

talus_hed = color.rgb2xyz(talus)

fig, ax = plt.subplots(2, 2)
ax[0][0].imshow(talus)
ax[0][0].set_title("RGB")
ax[0][1].imshow(color.gray2rgb(talus_hed[:,:,0]))
ax[0][1].set_title("XYZ 1")
ax[1][0].imshow(color.gray2rgb(talus_hed[:,:,1]))
ax[1][0].set_title("XYZ 2")
ax[1][1].imshow(color.gray2rgb(talus_hed[:,:,2]))
ax[1][1].set_title("XYZ 3")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## HSV with multiple image types

# %%
files = [
    {
        'description': 'Mischief Number 2',
        'filename': 'MiZ08-465R_9.JPG',
    },
    {
        'description': 'Low Contrast',
        'filename': 'GSR2013-9L.JPG',
    },
    {
        'description': 'Low Contrast with Corrosion',
        'filename': 'GSR2013-44L.JPG',
    },
    {
        'description': 'Very Low Contrast, with Hole',
        'filename': 'MiZ08-465L_11.JPG',
    },
    {
        'description': 'Good Contrast, Blue Background',
        'filename': 'GÖ_3_2000_3_L.JPG',
    },
    {
        'description': 'Dark Bone with Texture',
        'filename': 'GÖ_i_2000_1_L.JPG',
    },
    {
        'description': 'Dark Bone',
        'filename': 'GÖ_p_2013_188L.JPG',
    },
    {
        'description': 'Didnt work last time',
        'filename': 'GÖ_3_2012_421_R.JPG',
    }
]

for file in files:
    rgb_image = io.imread(DATA_PATH + file['filename'])
    hsv_image = color.rgb2hsv(rgb_image)
       
    file['rgb'] = rgb_image
    file['hsv'] = hsv_image
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/lib/python3.4/site-packages/skimage/util/dtype.py:107: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))

# %%
fig, ax = plt.subplots(len(files), 4)
for index, file in enumerate(files):
    ax[index][0].imshow(file['rgb'])
    ax[index][0].set_title("RGB")
    ax[index][1].imshow(color.gray2rgb(file['hsv'][:,:,0]))
    ax[index][1].set_title("HSV 1")
    ax[index][2].imshow(color.gray2rgb(file['hsv'][:,:,1]))
    ax[index][2].set_title("HSV 2")
    ax[index][3].imshow(color.gray2rgb(file['hsv'][:,:,2]))
    ax[index][3].set_title("HSV 3")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for index, file in enumerate(files):
    fig, ax = plt.subplots(1, 4)
    ax[0].imshow(file['rgb'])
    ax[0].set_title("RGB")
    ax[1].imshow(color.gray2rgb(file['rgb'][:,:,0]))
    ax[1].set_title("HSV 1")
    ax[2].imshow(color.gray2rgb(file['rgb'][:,:,1]))
    ax[2].set_title("HSV 2")
    ax[3].imshow(color.gray2rgb(file['rgb'][:,:,2]))
    ax[3].set_title("HSV 3")
# Out:
# Populating the interactive namespace from numpy and matplotlib
